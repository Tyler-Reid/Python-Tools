# %% [markdown]
# ## Traffic Data CSV Project

# %%
import pandas as pd
import os

# %% [markdown]
# #### Reading Single Month CSV File

# %%
df = pd.read_csv(r"C:\Users\TRHislop\Desktop\Essential\Python_Project_Folder\Traffic_Volume_CSV\volume_jan_2019.csv")


files = [file for file in os.listdir(r"C:\Users\TRHislop\Desktop\Essential\Python_Project_Folder\Traffic_Volume_CSV")]

all_months_data = pd.DataFrame()

for file in files: 
    df = pd.read_csv("C:\\Users\\TRHislop\\Desktop\\Essential\\Python_Project_Folder\\Traffic_Volume_CSV\\"+file)
    all_months_data = pd.concat([all_months_data, df])
                     
all_months_data.to_csv("all_data.csv", index=False)

# %% [markdown]
# #### Read in Updated dataframe

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#                  Sdate            Cosit  Study  Period  LaneNumber  \
# 0  2019-04-01 00:00:00  ="000010100042"      1      60           1
# 1  2019-04-01 00:00:00  ="000010100042"      1      60           2
# 2  2019-04-01 00:00:00  ="000010100042"      1      60           3
# 3  2019-04-01 00:00:00  ="000010100042"      1      60           4
# 4  2019-04-01 00:00:00  ="000010100042"      1      60           5
#
#      LaneDescription  LaneDirection DirectionDescription  Volume  Flags  \
# 0  Northbound Lane 1              1                North       0   8192
# 1  Northbound Lane 2              1                North      74   8192
# 2  Northbound Lane 3              1                North     113   8192
# 3  Northbound Lane 4              1                North      42   8192
# 4  Southbound Lane 1              2                South      68   8192
#
#   Flag Text  Setup  #Bins  Bins
# 0   Checked  32426      0   NaN
# 1   Checked  32426      0   NaN
# ...

# %% [markdown]
# #### What was the month with highest volume? How high was the volume in that month?

# %%
all_data['Month'] = all_data['Sdate'].str[5:7]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#                  Sdate            Cosit  Study  Period  LaneNumber  \
# 0  2019-04-01 00:00:00  ="000010100042"      1      60           1
# 1  2019-04-01 00:00:00  ="000010100042"      1      60           2
# 2  2019-04-01 00:00:00  ="000010100042"      1      60           3
# 3  2019-04-01 00:00:00  ="000010100042"      1      60           4
# 4  2019-04-01 00:00:00  ="000010100042"      1      60           5
#
#      LaneDescription  LaneDirection DirectionDescription  Volume  Flags  \
# 0  Northbound Lane 1              1                North       0   8192
# 1  Northbound Lane 2              1                North      74   8192
# 2  Northbound Lane 3              1                North     113   8192
# 3  Northbound Lane 4              1                North      42   8192
# 4  Southbound Lane 1              2                South      68   8192
#
#   Flag Text  Setup  #Bins  Bins  Month
# 0   Checked  32426      0   NaN      4
# 1   Checked  32426      0   NaN      4
# ...

# %% [markdown]
# #### Clean up the data

# %% [markdown]
# ###### Drop Rows of NaN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()

all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#                  Sdate            Cosit  Study  Period  LaneNumber  \
# 0  2019-04-01 00:00:00  ="000010100042"      1      60           1
# 1  2019-04-01 00:00:00  ="000010100042"      1      60           2
# 2  2019-04-01 00:00:00  ="000010100042"      1      60           3
# 3  2019-04-01 00:00:00  ="000010100042"      1      60           4
# 4  2019-04-01 00:00:00  ="000010100042"      1      60           5
#
#      LaneDescription  LaneDirection DirectionDescription  Volume  Flags  \
# 0  Northbound Lane 1              1                North       0   8192
# 1  Northbound Lane 2              1                North      74   8192
# 2  Northbound Lane 3              1                North     113   8192
# 3  Northbound Lane 4              1                North      42   8192
# 4  Southbound Lane 1              2                South      68   8192
#
#   Flag Text  Setup  #Bins  Bins  Month
# 0   Checked  32426      0   NaN      4
# 1   Checked  32426      0   NaN      4
# ...

# %% [markdown]
# #### Augment data with additional columns
