# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
df1 = pd.read_csv('Vaccine_Dashboard_2021_03_22_(PROD).csv')

# %%
df1.head()
# Out:
#    PrimaryKeyID  RECIP_ID RECIP_SEX RECIP_ETHNICITY              ADMIN_DATE  \
# 0        330201   2504510         F          2135-2  2021/03/14 09:00:00+00
# 1        330202   2504511         M          2186-5  2021/03/14 09:00:00+00
# 2        330203    338579         F          2186-5  2021/03/14 09:00:00+00
# 3        330204    556028         F          2186-5  2021/03/14 09:00:00+00
# 4        330205   2513143         U             UNK  2021/03/12 09:00:00+00
#
#    MVX  DOSE_NUM VAX_SERIES_COMPLETE  REGION_NUM  \
# 0  MOD         2                 YES         5.0
# 1  MOD         2                 YES         5.0
# 2  MOD         2                 YES         5.0
# 3  MOD         2                 YES         5.0
# 4  MOD         1                  NO         9.0
#
#                    BEHAVIORAL_REGION  BOROUGH_FIPS               BOROUGH_NAME  \
# 0           Matanuska-Susitna Region         170.0  Matanuska-Susitna Borough
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370087 entries, 0 to 370086
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   PrimaryKeyID         370087 non-null  int64
#  1   RECIP_ID             370087 non-null  int64
#  2   RECIP_SEX            370087 non-null  object
#  3   RECIP_ETHNICITY      370087 non-null  object
#  4   ADMIN_DATE           370087 non-null  object
#  5   MVX                  369983 non-null  object
#  6   DOSE_NUM             370087 non-null  int64
#  7   VAX_SERIES_COMPLETE  370087 non-null  object
#  8   REGION_NUM           363477 non-null  float64
#  9   BEHAVIORAL_REGION    363477 non-null  object
#  10  BOROUGH_FIPS         363477 non-null  float64
#  11  BOROUGH_NAME         363477 non-null  object
#  12  ADJ_BOROUGH_FIPS     363477 non-null  float64
#  13  ADJ_BOROUGH_NAME     363477 non-null  object
#  14  combrace             370087 non-null  object
# ...

# %%
df1['BOROUGH_NAME'].value_counts()
# Out:
# Anchorage Municipality               151780
# Fairbanks North Star Borough          35104
# Matanuska-Susitna Borough             33442
# Kenai Peninsula Borough               25994
# Juneau City and Borough               20883
# Bethel Census Area                    13577
# Kodiak Island Borough                  8176
# Nome Census Area                       8159
# Ketchikan Gateway Borough              8091
# Sitka City and Borough                 8035
# Chugach-Copper River Census Area       5138
# Kusilvak Census Area                   5077
# Northwest Arctic Borough               4692
# Yukon-Koyukuk Census Area              4463
# North Slope Borough                    4031
# Prince of Wales-Hyder Census Area      3560
# Petersburg Borough                     3102
# Dillingham Census Area                 2782
# Haines Borough                         2369
# Aleutians West Census Area             2268
# Southeast Fairbanks Census Area        2262
# ...

# %%
boroughs = df1['BOROUGH_NAME']
vaccinations = df1['BOROUGH_NAME'].value_counts()

plt.bar(df1['BOROUGH_NAME'], df1['BOROUGH_NAME'].value_counts())

plt.title('Total Vaccinations by Borough')
plt.xlabel('Boroughs')
plt.ylabel('Total Vaccinations')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-2e649776f8d0> in <module>
#       2 vaccinations = df1['BOROUGH_NAME'].value_counts()
#       3
# ----> 4 plt.bar(df1['BOROUGH_NAME'], df1['BOROUGH_NAME'].value_counts())
#       5
#       6 plt.title('Total Vaccinations by Borough')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...
